# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file='Sleep_health_and_lifestyle_dataset.csv'
df=pd.read_csv(file)

# %%
df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
df.describe()
# Out:
#         Person ID         Age  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000      374.000000        374.000000
# mean   187.500000   42.184492        7.132086          7.312834
# std    108.108742    8.673133        0.795657          1.196956
# min      1.000000   27.000000        5.800000          4.000000
# 25%     94.250000   35.250000        6.400000          6.000000
# 50%    187.500000   43.000000        7.200000          7.000000
# 75%    280.750000   50.000000        7.800000          8.000000
# max    374.000000   59.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  Heart Rate   Daily Steps
# count               374.000000    374.000000  374.000000    374.000000
# mean                 59.171123      5.385027   70.165775   6816.844920
# std                  20.830804      1.774526    4.135676   1617.915679
# min                  30.000000      3.000000   65.000000   3000.000000
# ...

# %%
df.mean()
# Out:
# Person ID                   187.500000
# Age                          42.184492
# Sleep Duration                7.132086
# Quality of Sleep              7.312834
# Physical Activity Level      59.171123
# Stress Level                  5.385027
# Heart Rate                   70.165775
# Daily Steps                6816.844920
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           374 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
df.corr()
# Out:
#                          Person ID       Age  Sleep Duration  \
# Person ID                 1.000000  0.990516        0.296305
# Age                       0.990516  1.000000        0.344709
# Sleep Duration            0.296305  0.344709        1.000000
# Quality of Sleep          0.431612  0.473734        0.883213
# Physical Activity Level   0.149882  0.178993        0.212360
# Stress Level             -0.394287 -0.422344       -0.811023
# Heart Rate               -0.225467 -0.225606       -0.516455
# Daily Steps               0.043844  0.057973       -0.039533
#
#                          Quality of Sleep  Physical Activity Level  \
# Person ID                        0.431612                 0.149882
# Age                              0.473734                 0.178993
# Sleep Duration                   0.883213                 0.212360
# Quality of Sleep                 1.000000                 0.192896
# Physical Activity Level          0.192896                 1.000000
# ...

# %%
df.nunique()
# Out:
# Person ID                  374
# Gender                       2
# Age                         31
# Occupation                  11
# Sleep Duration              27
# Quality of Sleep             6
# Physical Activity Level     16
# Stress Level                 6
# BMI Category                 4
# Blood Pressure              25
# Heart Rate                  19
# Daily Steps                 20
# Sleep Disorder               3
# dtype: int64

# %%
df["Occupation"].value_counts()
# Out:
# Nurse                   73
# Doctor                  71
# Engineer                63
# Lawyer                  47
# Teacher                 40
# Accountant              37
# Salesperson             32
# Software Engineer        4
# Scientist                4
# Sales Representative     2
# Manager                  1
# Name: Occupation, dtype: int64

# %%
df['Occupation'].mask(df['Occupation'] == 'Engineer', 0, inplace=True)
df['Occupation'].mask(df['Occupation'] == 'Software Engineer', 0, inplace=True)
df['Occupation'].mask(df['Occupation'] == 'Scientist', 0, inplace=True)
#science

# %%
df['Occupation'].mask(df['Occupation'] == 'Nurse', 1, inplace=True)
df['Occupation'].mask(df['Occupation'] == 'Doctor', 1, inplace=True)
#healt

# %%
#sale
df['Occupation'].mask(df['Occupation'] == 'Salesperson', 2, inplace=True)
df['Occupation'].mask(df['Occupation'] == 'Sales Representative', 2, inplace=True)
df['Occupation'].mask(df['Occupation'] == 'Accountant', 2, inplace=True)

# %%
#education
df['Occupation'].mask(df['Occupation'] == 'Teacher', 3, inplace=True)

# %%
#law
df['Occupation'].mask(df['Occupation'] == 'Lawyer', 2, inplace=True)

# %%
row_num = df[df['Occupation'] == 'Manager'].index
row_num
# Out:
# Int64Index([263], dtype='int64')

# %%
df= df.drop(labels=[263], axis=0)

# %%
df["Occupation"].value_counts()
# Out:
# 1    144
# 2    118
# 0     71
# 3     40
# Name: Occupation, dtype: int64

# %%
df['Occupation'] = df['Occupation'].astype(str).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 373 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                373 non-null    int64
#  1   Gender                   373 non-null    object
#  2   Age                      373 non-null    int64
#  3   Occupation               373 non-null    int32
#  4   Sleep Duration           373 non-null    float64
#  5   Quality of Sleep         373 non-null    int64
#  6   Physical Activity Level  373 non-null    int64
#  7   Stress Level             373 non-null    int64
#  8   BMI Category             373 non-null    object
#  9   Blood Pressure           373 non-null    object
#  10  Heart Rate               373 non-null    int64
#  11  Daily Steps              373 non-null    int64
#  12  Sleep Disorder           373 non-null    object
# dtypes: float64(1), int32(1), int64(7), object(4)
# ...

# %%
# Plot
plt.figure(figsize=(15,15), dpi= 80)
sns.heatmap(df.corr(), xticklabels=df.corr().columns, yticklabels=df.corr().columns, cmap='RdYlGn', center=0, annot=True)

# Decorations
plt.title('Correlogram of mtcars', fontsize=22)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# %%
#highest relation is ram and price
#front camera and primary camera
#4g and 3g
#for price=ram>battery>pixels

# %%
lists = sorted(zip(*[df['Age'],df['Quality of Sleep']]))
new_x, new_y = list(zip(*lists))


plt.plot(new_x,new_y,c='b',label='quality of sleep')


plt.xlabel('Age')
plt.ylabel('quality of sleep')
plt.legend()
plt.show()

# %%
lists = sorted(zip(*[df['Stress Level'],df['Quality of Sleep']]))
new_x, new_y = list(zip(*lists))


plt.xlabel('stress label')
plt.ylabel('quality of sleep')

plt.plot(new_x, new_y)
plt.show()

# %%
df["Sleep Disorder"].value_counts()
# Out:
# None           218
# Sleep Apnea     78
# Insomnia        77
# Name: Sleep Disorder, dtype: int64

# %%
def encode(x):
    if x == "Normal":
        return 1
    elif x == "Overweight":
        return 2
    else:
        return 3

df["BMI_Category_encode"] = df.apply(lambda x: encode(x["BMI Category"]), axis = 1)

# %%
gb = df.groupby('Sleep Disorder')
none = gb.get_group('None')
sleep_apnea=gb.get_group('Sleep Apnea')
ınsomnia=gb.get_group('Insomnia')

# %%
a=none["BMI_Category_encode"].mean()
b=sleep_apnea["BMI_Category_encode"].mean()
c=ınsomnia["BMI_Category_encode"].mean()

# %%
X = ['none','insomnia','sleep apnea']
y = [a,c,b]


color1 = '#B35E5E'



bar1 = np.arange(len(X))


plt.figure(figsize=(10,10), dpi= 80)

plt.bar(bar1, y, color = color1)


  

plt.xlabel("SLEEP DİSORDERS")
plt.ylabel("BMI mean values")

plt.xticks(bar1+0.01,X)


plt.show()

# %%
df["gender_encode"] = pd.get_dummies(df["Gender"]
                          
                          ,drop_first = True)
df
# Out:
#      Person ID  Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 0            1    Male   27           0             6.1                 6
# 1            2    Male   28           1             6.2                 6
# 2            3    Male   28           1             6.2                 6
# 3            4    Male   28           2             5.9                 4
# 4            5    Male   28           2             5.9                 4
# ..         ...     ...  ...         ...             ...               ...
# 369        370  Female   59           1             8.1                 9
# 370        371  Female   59           1             8.0                 9
# 371        372  Female   59           1             8.1                 9
# 372        373  Female   59           1             8.1                 9
# 373        374  Female   59           1             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# ...

# %%
df["gender_encode"] = pd.get_dummies(df["Gender"]
                          
                          ,drop_first = True)
df
# male=1,female=0
# Out:
#      Person ID  Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 0            1    Male   27           0             6.1                 6
# 1            2    Male   28           1             6.2                 6
# 2            3    Male   28           1             6.2                 6
# 3            4    Male   28           2             5.9                 4
# 4            5    Male   28           2             5.9                 4
# ..         ...     ...  ...         ...             ...               ...
# 369        370  Female   59           1             8.1                 9
# 370        371  Female   59           1             8.0                 9
# 371        372  Female   59           1             8.1                 9
# 372        373  Female   59           1             8.1                 9
# 373        374  Female   59           1             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# ...

# %%
def encode(x):
    if x == "Normal":
        return 1
    elif x == "Overweight":
        return 2
    else:
        return 3

df["BMI_Category_encode"] = df.apply(lambda x: encode(x["BMI Category"]), axis = 1)

# %%
df
# Out:
#      Person ID  Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 0            1    Male   27           0             6.1                 6
# 1            2    Male   28           1             6.2                 6
# 2            3    Male   28           1             6.2                 6
# 3            4    Male   28           2             5.9                 4
# 4            5    Male   28           2             5.9                 4
# ..         ...     ...  ...         ...             ...               ...
# 369        370  Female   59           1             8.1                 9
# 370        371  Female   59           1             8.0                 9
# 371        372  Female   59           1             8.1                 9
# 372        373  Female   59           1             8.1                 9
# 373        374  Female   59           1             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# ...

# %%
df["Sleep Disorder"].value_counts()
# Out:
# None           218
# Sleep Apnea     78
# Insomnia        77
# Name: Sleep Disorder, dtype: int64

# %%
# önce bu şekilde dene ondan sonra hasta veya hasta değil şeklinde ayarla

# %%
def encode(x):
    if x == "None":
        return 1
    elif x == "Sleep Apnea":
        return 2
    else:
        return 3

df["sleep_disorder_encode"] = df.apply(lambda x: encode(x["Sleep Disorder"]), axis = 1)

# %%
df
# Out:
#      Person ID  Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 0            1    Male   27           0             6.1                 6
# 1            2    Male   28           1             6.2                 6
# 2            3    Male   28           1             6.2                 6
# 3            4    Male   28           2             5.9                 4
# 4            5    Male   28           2             5.9                 4
# ..         ...     ...  ...         ...             ...               ...
# 369        370  Female   59           1             8.1                 9
# 370        371  Female   59           1             8.0                 9
# 371        372  Female   59           1             8.1                 9
# 372        373  Female   59           1             8.1                 9
# 373        374  Female   59           1             8.1                 9
#
#      Physical Activity Level  Stress Level BMI Category Blood Pressure  \
# ...

# %%
newdf = df.drop("Gender" ,axis='columns')

# %%
df.drop(['BMI Category', 'Sleep Disorder','Gender','Person ID'], axis=1,inplace=True)

# %%
df
# Out:
#      Age  Occupation  Sleep Duration  Quality of Sleep  \
# 0     27           0             6.1                 6
# 1     28           1             6.2                 6
# 2     28           1             6.2                 6
# 3     28           2             5.9                 4
# 4     28           2             5.9                 4
# ..   ...         ...             ...               ...
# 369   59           1             8.1                 9
# 370   59           1             8.0                 9
# 371   59           1             8.1                 9
# 372   59           1             8.1                 9
# 373   59           1             8.1                 9
#
#      Physical Activity Level  Stress Level Blood Pressure  Heart Rate  \
# 0                         42             6         126/83          77
# 1                         60             8         125/80          75
# 2                         60             8         125/80          75
# ...

# %%
df["Blood Pressure"].value_counts()
# Out:
# 130/85    99
# 140/95    65
# 125/80    65
# 120/80    45
# 115/75    32
# 135/90    27
# 140/90     4
# 125/82     3
# 128/85     3
# 132/87     3
# 118/75     2
# 130/86     2
# 119/77     2
# 131/86     2
# 126/83     2
# 117/76     2
# 135/88     2
# 129/84     2
# 142/92     2
# 128/84     2
# 115/78     2
# 139/91     2
# 122/80     1
# 121/79     1
# 118/76     1
# Name: Blood Pressure, dtype: int64

# %%
df["systolic_blood_pressure"]=df["Blood Pressure"].str.split('/').str[0]

# %%
df["diastolic_blood_pressure"]=df["Blood Pressure"].str.split('/').str[1]

# %%
#df["Blood Pressure"]=df["Blood Pressure"].replace('/', '.', regex=True)

# %%
df
# Out:
#      Age  Occupation  Sleep Duration  Quality of Sleep  \
# 0     27           0             6.1                 6
# 1     28           1             6.2                 6
# 2     28           1             6.2                 6
# 3     28           2             5.9                 4
# 4     28           2             5.9                 4
# ..   ...         ...             ...               ...
# 369   59           1             8.1                 9
# 370   59           1             8.0                 9
# 371   59           1             8.1                 9
# 372   59           1             8.1                 9
# 373   59           1             8.1                 9
#
#      Physical Activity Level  Stress Level Blood Pressure  Heart Rate  \
# 0                         42             6         126/83          77
# 1                         60             8         125/80          75
# 2                         60             8         125/80          75
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 373 entries, 0 to 373
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       373 non-null    int64
#  1   Occupation                373 non-null    int32
#  2   Sleep Duration            373 non-null    float64
#  3   Quality of Sleep          373 non-null    int64
#  4   Physical Activity Level   373 non-null    int64
#  5   Stress Level              373 non-null    int64
#  6   Blood Pressure            373 non-null    object
#  7   Heart Rate                373 non-null    int64
#  8   Daily Steps               373 non-null    int64
#  9   BMI_Category_encode       373 non-null    int64
#  10  gender_encode             373 non-null    uint8
#  11  sleep_disorder_encode     373 non-null    int64
#  12  systolic_blood_pressure   373 non-null    object
#  13  diastolic_blood_pressure  373 non-null    object
# ...

# %%
df.drop(['Blood Pressure'], axis=1,inplace=True)

# %%
#df['systolic_blood_pressure'] = df['Blood Pressure'].astype(str).astype(float)

# %%
inputs = df.drop('sleep_disorder_encode',axis='columns')
target = df.sleep_disorder_encode

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(inputs,target,test_size=0.3)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()

# %%
model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
model.score(X_test,y_test) # AM I DA BESTTT?????
# Out:
# 0.9107142857142857

# %%
X_test[0:10]
# Out:
#      Age  Occupation  Sleep Duration  Quality of Sleep  \
# 137   38           2             7.1                 8
# 59    32           1             7.7                 7
# 150   39           2             8.0                 9
# 35    31           1             6.1                 6
# 92    35           0             7.5                 8
# 344   57           1             8.2                 9
# 123   37           2             7.2                 8
# 84    35           0             7.5                 8
# 166   41           0             7.3                 8
# 202   43           0             7.8                 8
#
#      Physical Activity Level  Stress Level  Heart Rate  Daily Steps  \
# 137                       60             5          68         8000
# 59                        75             6          70         8000
# 150                       80             3          67         7500
# 35                        30             8          72         5000
# ...

# %%
y_test[0:10]
# Out:
# 137    1
# 59     1
# 150    1
# 35     1
# 92     1
# 344    2
# 123    1
# 84     1
# 166    1
# 202    3
# Name: sleep_disorder_encode, dtype: int64

# %%
model.predict(X_test[0:10])
# Out:
# array([1, 1, 1, 1, 1, 2, 1, 1, 1, 1], dtype=int64)

# %%
model.predict_proba(X_test[:10])
# Out:
# array([[9.98945934e-01, 6.50238300e-06, 1.04756334e-03],
#        [9.99999994e-01, 5.97613560e-09, 2.93284772e-10],
#        [9.99996084e-01, 3.91558691e-06, 6.21064164e-13],
#        [9.93558659e-01, 2.03871494e-07, 6.44113750e-03],
#        [9.99999111e-01, 4.85699024e-07, 4.03194581e-07],
#        [1.20587121e-05, 9.99987941e-01, 8.14732062e-14],
#        [9.99999997e-01, 3.55149851e-10, 2.68862371e-09],
#        [9.99999111e-01, 4.85699024e-07, 4.03194581e-07],
#        [9.99982397e-01, 2.11760185e-06, 1.54853924e-05],
#        [9.99982081e-01, 1.79190178e-05, 8.96580981e-11]])

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(GaussianNB(),X_train, y_train, cv=5)
# Out:
# array([0.9245283 , 0.82692308, 0.92307692, 0.90384615, 0.82692308])

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=100, max_depth = 6, random_state=42)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=6, random_state=42)

# %%
rf.score(X_test,y_test)
# Out:
# 0.9285714285714286

# %%
y_test[0:10]
# Out:
# 137    1
# 59     1
# 150    1
# 35     1
# 92     1
# 344    2
# 123    1
# 84     1
# 166    1
# 202    3
# Name: sleep_disorder_encode, dtype: int64

# %%
model.predict(X_test[0:10])
# Out:
# array([1, 1, 1, 1, 1, 2, 1, 1, 1, 1], dtype=int64)

# %%
rf.predict(X_test[0:10])
